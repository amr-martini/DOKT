# %%
import numpy as np
import pandas as pd

# %%
np.argmax?

# %%
delays = pd.read_csv('delays.csv', header=-1).__array__().T
lambda2 = pd.read_csv('lambda2.csv', header=-1).__array__()

delays = delays[:,2:]
lambda2 = lambda2[:,2:]

# %%
q2 = 25

# %%
import matplotlib.pyplot as plt

# %matplotlib notebook

plt.figure()
for i,d in enumerate(delays):
    plt.plot(d,((25-25/(1+lambda2)) + q2*d)[0], label='{} fps'.format((i+1)*30))
    
plt.legend()
plt.xlabel('Delay (frames)')
plt.ylabel('MSE')
plt.title('MSE predictor objective with motion covariance = 0.075')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'MSE predictor objective with motion covariance = 0.075')

# %%
for d in delays:
    print d
# Out:
# [0.18576 0.28916 0.43668 0.53294 0.69455 0.90782 1.1257  1.3633 ]
# [0.4483  0.56064 0.80876 1.0562  1.4111  1.8159  2.2622  2.8335 ]
# [0.56813 0.94013 1.2731  1.6662  2.3192  2.8737  3.4147  7.6012 ]
# [0.82755 1.2137  1.5744  2.2073  2.9515  3.9066  4.5684  5.7445 ]
# [0.92883 1.4232  2.0224  2.659   3.5543  4.5195  5.7303  7.0188 ]
# [1.8223 1.6854 2.4041 3.2174 4.2919 5.421  6.7931 8.1642]

# %%
print lambda2
# Out:
# [[1.3985e+00 6.5931e-01 3.9578e-01 2.2110e-01 2.7131e-01 8.3893e-02
#   5.5058e-02 1.9125e-04]]
